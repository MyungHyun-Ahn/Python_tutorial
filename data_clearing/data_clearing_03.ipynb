# %%
# 데이터 클리닝 유일성
import pandas as pd

# %%
df = pd.read_csv('data/dust.csv')
df.head()
# Out:
#         날짜  서울  부산  대구  인천  광주  대전  울산  경기  강원  충북  충남  전북  전남  세종  경북  경남  \
# 0  08월 11일   7  17  15  10  29  12  12   9  16  14  16  25  21  11  14  24
# 1  08월 10일  15  25  15  20  28  25  17  20  16  25  29  29  25  27  14  29
# 2  08월 09일  24  26  26  27  27  27  22  27  25  32  24  24  27  26  25  38
# 3  08월 08일  26  25  28  26  29  31  20  26  29  33  26  29  31  31  28  32
# 4  08월 07일  20  26  22  25  33  24  18  23  18  23  29  33  29  27  19  28
#
#    제주  강원.1
# 0  21    16
# 1  23    16
# 2  25    25
# 3  27    29
# 4  26    18

# %%
df.drop_duplicates(inplace=True)

# %%
df.value_counts('날짜')
# Out:
# 날짜
# 07월 13일    1
# 07월 14일    1
# 08월 10일    1
# 08월 09일    1
# 08월 08일    1
# 08월 07일    1
# 08월 06일    1
# 08월 05일    1
# 08월 04일    1
# 08월 03일    1
# 08월 02일    1
# 08월 01일    1
# 07월 31일    1
# 07월 30일    1
# 07월 29일    1
# 07월 28일    1
# 07월 27일    1
# 07월 26일    1
# 07월 25일    1
# 07월 24일    1
# 07월 23일    1
# 07월 22일    1
# 07월 21일    1
# 07월 20일    1
# 07월 19일    1
# 07월 18일    1
# 07월 17일    1
# 07월 16일    1
# 07월 15일    1
# 08월 11일    1
# dtype: int64

# %%
df = df.T.drop_duplicates().T # 가로로 바꿔준뒤 중복되는 행 삭제후 다시 되돌린값을 df에 저장

# %%
df
# Out:
#          날짜  서울  부산  대구  인천  광주  대전  울산  경기  강원  충북  충남  전북  전남  세종  경북  경남  \
# 0   08월 11일   7  17  15  10  29  12  12   9  16  14  16  25  21  11  14  24
# 1   08월 10일  15  25  15  20  28  25  17  20  16  25  29  29  25  27  14  29
# 2   08월 09일  24  26  26  27  27  27  22  27  25  32  24  24  27  26  25  38
# 3   08월 08일  26  25  28  26  29  31  20  26  29  33  26  29  31  31  28  32
# 4   08월 07일  20  26  22  25  33  24  18  23  18  23  29  33  29  27  19  28
# 5   08월 06일  31  39  29  35  27  31  31  30  22  33  28  27  30  34  29  37
# 6   08월 05일  27  36  25  31  27  24  30  27  25  31  25  26  25  25  28  31
# 7   08월 04일  27  36  26  31  27  27  32  31  39  36  30  27  27  29  29  36
# 8   08월 03일  44  32  23  47  29  28  29  44  33  31  34  27  28  32  28  31
# 9   08월 02일  40  26  20  41  26  19  20  39  25  24  33  29  22  24  22  27
# 10  08월 01일  33  26  22  40  24  18  26  35  20  26  36  30  23  28  21  25
# ...
