# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
main_df = pd.read_csv('data/titanic.csv')
main_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
count_age = main_df[['Age', 'PassengerId']]
count_age
# Out:
#       Age  PassengerId
# 0    22.0            1
# 1    38.0            2
# 2    26.0            3
# 3    35.0            4
# 4    35.0            5
# ..    ...          ...
# 886  27.0          887
# 887  19.0          888
# 888   NaN          889
# 889  26.0          890
# 890  32.0          891
#
# [891 rows x 2 columns]

# %%
count_age = count_age.dropna(subset='Age')
count_age
# Out:
#       Age  PassengerId
# 0    22.0            1
# 1    38.0            2
# 2    26.0            3
# 3    35.0            4
# 4    35.0            5
# ..    ...          ...
# 885  39.0          886
# 886  27.0          887
# 887  19.0          888
# 889  26.0          890
# 890  32.0          891
#
# [714 rows x 2 columns]

# %%
count_age['Age'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Fare_df = main_df[['Fare', 'Age']]

# %%
Fare_df.sort_values('Fare', ascending=False)
# Out:
#          Fare   Age
# 258  512.3292  35.0
# 737  512.3292  35.0
# 679  512.3292  36.0
# 88   263.0000  23.0
# 27   263.0000  19.0
# ..        ...   ...
# 633    0.0000   NaN
# 413    0.0000   NaN
# 822    0.0000  38.0
# 732    0.0000   NaN
# 674    0.0000   NaN
#
# [891 rows x 2 columns]

# %%
main_df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
main_df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
main_df[(main_df['Pclass'] == 1) & (main_df['Survived'] == 1)]['PassengerId'].count()
# Out:
# 136

# %%
main_df[(main_df['Pclass'] == 2) & (main_df['Survived'] == 1)]['PassengerId'].count()
# Out:
# 87

# %%
main_df[(main_df['Pclass'] == 3) & (main_df['Survived'] == 1)]['PassengerId'].count()
# Out:
# 119

# %%
136/216
# Out:
# 0.6296296296296297

# %%
87/184
# Out:
# 0.47282608695652173

# %%
119/491
# Out:
# 0.24236252545824846

# %%
sns.jointplot(data=main_df, x='Age', y='Survived')

# %%
sns.heatmap(main_df[['Age', 'Survived', 'Sex']].corr())
# Out:
# <AxesSubplot:>

# %%
main_df.plot(kind='scatter', x='Age', y='Fare')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.kdeplot(main_df['Pclass'], main_df['Survived'])
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.stripplot(data=main_df, x='Survived', y='Age')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.violinplot(data=main_df, x='Survived', y='Age')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.stripplot(data=main_df, x='Survived', y='Age', hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>
