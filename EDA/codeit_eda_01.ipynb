# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/occupations.csv')
df.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
f_df = df[df['gender'] == 'F']
f_df
# Out:
#      user_id  age gender  occupation zip_code
# 1          2   53      F       other    94043
# 4          5   33      F       other    15213
# 10        11   39      F       other    30329
# 11        12   28      F       other    06405
# 14        15   49      F    educator    97301
# ..       ...  ...    ...         ...      ...
# 924      925   18      F    salesman    49036
# 929      930   28      F   scientist    07310
# 937      938   38      F  technician    55038
# 938      939   26      F     student    33319
# 941      942   48      F   librarian    78209
#
# [273 rows x 5 columns]

# %%
f_df['occupation'].value_counts().sort_values(ascending=False)
# Out:
# student          60
# other            36
# administrator    36
# librarian        29
# educator         26
# writer           19
# artist           13
# healthcare       11
# marketing        10
# programmer        6
# homemaker         6
# none              4
# executive         3
# scientist         3
# salesman          3
# engineer          2
# lawyer            2
# entertainment     2
# retired           1
# technician        1
# Name: occupation, dtype: int64

# %%
m_df = df[df['gender'] == 'M']
m_df['occupation'].value_counts().sort_values(ascending=False)
# Out:
# student          136
# other             69
# educator          69
# engineer          65
# programmer        60
# administrator     43
# executive         29
# scientist         28
# technician        26
# writer            26
# librarian         22
# entertainment     16
# marketing         16
# artist            15
# retired           13
# lawyer            10
# salesman           9
# doctor             7
# none               5
# healthcare         5
# homemaker          1
# Name: occupation, dtype: int64
