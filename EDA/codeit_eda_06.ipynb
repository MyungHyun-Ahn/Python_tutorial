# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
sur_df = pd.read_csv('data/young_survey.csv')

# %%
sns.heatmap(sur_df[['Branded clothing', 'Spending on looks']].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(sur_df[['Writing notes', 'New environment']].corr(), annot=True)
# Out:
# <AxesSubplot:>
